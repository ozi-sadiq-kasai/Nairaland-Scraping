# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
response = requests.get("https://www.vanguardngr.com/2019/02/2019-presidential-election-results-buhari-polled-over15m-votes/")
soup = BeautifulSoup(response.content, "html.parser")

# %%
'''get_contents = soup.find_all(attrs={"class": "wikitable"})
strip_contents = [x.get_text() for x in get_contents]

df = pd.DataFrame(strip_contents)
df.to_csv('2015_elections.csv')'''

# %%
from multiprocessing import get_context

content = soup.find('p')
print(content)
# Out:
# <p data-translate="blocked_why_detail">This website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.</p>
